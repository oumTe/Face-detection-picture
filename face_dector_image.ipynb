# %%
from google.colab.patches import cv2_imshow
from random import randrange

# %%
from google.colab import files
import cv2
import matplotlib.pyplot as plt

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-32c54a45-dacf-4c39-8a73-45a075cfd9e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32c54a45-dacf-4c39-8a73-45a075cfd9e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default.xml

# %%
trained_face_data=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c513f621-fd2d-4b6b-85cf-0310b9b6f2b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c513f621-fd2d-4b6b-85cf-0310b9b6f2b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving face2.png to face2.png

# %%
img=cv2.imread('face2.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
grayscaled_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayscaled_img)

# %%
face_coordinates = trained_face_data.detectMultiScale(grayscaled_img)
print(face_coordinates)
# Out:
# [[195   9  26  26]
#  [108  24  38  38]
#  [235  17  45  45]
#  [ 58  62  48  48]
#  [173  83  52  52]
#  [307  76  51  51]
#  [258 111  56  56]
#  [ 98 141  54  54]]

# %%
for (x,y,w,h) in face_coordinates:
    cv2.rectangle(img,(x,y),(x+w,y+h),(randrange(128,256),randrange(128,256),randrange(128,256)),2)
    plt.imshow(img)
